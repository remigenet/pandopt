# %%
from PandOpt import pandopt
import pandas as pd
import numpy as np
import tqdm 
import pandas as pd
import numpy as np
import timeit
import functools

# %%
def agg_sum(z):
    return np.sum(z, axis=1)

def agg_mean(z):
    return np.mean(z)

def agg_max(z):
    return np.max(z)

def agg_min(z):
    return np.min(z)

def agg_std(z):
    return np.std(z)

# %%
def measure_performance(df, func, window_size=3):
    try:
        operation = functools.partial(df.rolling(window=window_size).apply, func, raw=True)

        start_time = timeit.default_timer()
        result = operation()
        elapsed_time = timeit.default_timer() - start_time
        return np.sum(result, axis=0), elapsed_time, None
    except Exception as e:
        return None, None, str(e)

def run_tests(data_size, agg_funcs):
    results = {}
    total_tests = (data_size - 1) * len(agg_funcs) 
    progress_bar = tqdm.tqdm(total=total_tests, desc="Running Tests", ncols=100)

    for test_num in range(1, data_size):
        df_size = int(10**test_num)
        for func in agg_funcs:
            for test_iter in range(15):
                pandas_df = pd.DataFrame(np.random.randn(df_size, 4), columns=['A', 'B', 'C', 'D']).astype(np.float32)
                pandopt_df = pandopt(pandas_df)
                pandas_checksum, pandas_time, pandas_error = measure_performance(pandas_df, func)
                pandopt_checksum, pandopt_time, pandopt_error = measure_performance(pandopt_df, func)

                key = f"Size: 10^{test_num}, Func: {func.__name__}, Test: {test_iter}"
                results[key] = {
                    "Pandas Time (s)": pandas_time,
                    "Pandopt Time (s)": pandopt_time,
                    "Checksum Pandas": pandas_checksum,
                    "Checksum Pandopt": pandopt_checksum,
                    "Pandas Error": pandas_error,
                    "Pandopt Error": pandopt_error
                }

            progress_bar.update(1)

    progress_bar.close()
    return pd.DataFrame.from_dict(results, orient='index')

agg_functions = [agg_sum, agg_mean, agg_max, agg_min, agg_std]

results_df = run_tests(data_size=5, agg_funcs=agg_functions)
results_df
# Out:
# Running Tests:   0%|                                                         | 0/20 [00:00<?, ?it/s]/home/remi/.pyenv/versions/3.12.1/lib/python3.12/site-packages/numba/core/typed_passes.py:336: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see https://numba.readthedocs.io/en/stable/user/parallel.html#diagnostics for help.
#
# File "<ast>", line 2:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(errors.NumbaPerformanceWarning(msg,
# Running Tests:   5%|██▍                                              | 1/20 [00:01<00:23,  1.25s/it]Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Running Tests:  10%|████▉                                            | 2/20 [00:01<00:15,  1.14it/s]Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Running Tests:  15%|███████▎                                         | 3/20 [00:02<00:13,  1.22it/s]Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Running Tests:  20%|█████████▊                                       | 4/20 [00:03<00:11,  1.38it/s]Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Running Tests:  25%|████████████▎                                    | 5/20 [00:04<00:13,  1.12it/s]/home/remi/.pyenv/versions/3.12.1/lib/python3.12/site-packages/numba/core/typed_passes.py:336: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see https://numba.readthedocs.io/en/stable/user/parallel.html#diagnostics for help.
#
# File "<ast>", line 2:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(errors.NumbaPerformanceWarning(msg,
# Running Tests:  30%|██████████████▋                                  | 6/20 [00:05<00:12,  1.13it/s]Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Running Tests:  35%|█████████████████▏                               | 7/20 [00:05<00:09,  1.37it/s]Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Running Tests:  40%|███████████████████▌                             | 8/20 [00:06<00:07,  1.58it/s]Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Running Tests:  45%|██████████████████████                           | 9/20 [00:06<00:06,  1.77it/s]Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Running Tests:  50%|████████████████████████                        | 10/20 [00:07<00:06,  1.50it/s]/home/remi/.pyenv/versions/3.12.1/lib/python3.12/site-packages/numba/core/typed_passes.py:336: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see https://numba.readthedocs.io/en/stable/user/parallel.html#diagnostics for help.
#
# File "<ast>", line 2:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(errors.NumbaPerformanceWarning(msg,
# Running Tests:  55%|██████████████████████████▍                     | 11/20 [00:08<00:06,  1.30it/s]Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Running Tests:  60%|████████████████████████████▊                   | 12/20 [00:09<00:06,  1.28it/s]Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Running Tests:  65%|███████████████████████████████▏                | 13/20 [00:09<00:05,  1.30it/s]Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Running Tests:  70%|█████████████████████████████████▌              | 14/20 [00:10<00:04,  1.32it/s]Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Running Tests:  75%|████████████████████████████████████            | 15/20 [00:12<00:05,  1.06s/it]/home/remi/.pyenv/versions/3.12.1/lib/python3.12/site-packages/numba/core/typed_passes.py:336: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see https://numba.readthedocs.io/en/stable/user/parallel.html#diagnostics for help.
#
# File "<ast>", line 2:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(errors.NumbaPerformanceWarning(msg,
# Running Tests:  80%|██████████████████████████████████████▍         | 16/20 [00:15<00:06,  1.65s/it]Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Running Tests:  85%|████████████████████████████████████████▊       | 17/20 [00:20<00:07,  2.54s/it]Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Running Tests:  90%|███████████████████████████████████████████▏    | 18/20 [00:24<00:05,  2.96s/it]Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Running Tests:  95%|█████████████████████████████████████████████▌  | 19/20 [00:27<00:03,  3.26s/it]Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Error in pandoptRoll apply: DataFrame constructor not properly called!
# Running Tests: 100%|████████████████████████████████████████████████| 20/20 [00:39<00:00,  1.95s/it]
#                                      Pandas Time (s)  Pandopt Time (s)  \
# Size: 10^1, Func: agg_sum, Test: 0               NaN          1.243996
# Size: 10^1, Func: agg_sum, Test: 1               NaN          0.000143
# Size: 10^1, Func: agg_sum, Test: 2               NaN          0.000107
# Size: 10^1, Func: agg_sum, Test: 3               NaN          0.000105
# Size: 10^1, Func: agg_sum, Test: 4               NaN          0.000110
# ...                                              ...               ...
# Size: 10^4, Func: agg_std, Test: 10         0.561268               NaN
# Size: 10^4, Func: agg_std, Test: 11         0.562555               NaN
# Size: 10^4, Func: agg_std, Test: 12         0.559817               NaN
# Size: 10^4, Func: agg_std, Test: 13         0.566073               NaN
# Size: 10^4, Func: agg_std, Test: 14         0.561244               NaN
#
#                                                                        Checksum Pandas  \
# Size: 10^1, Func: agg_sum, Test: 0                                                None
# Size: 10^1, Func: agg_sum, Test: 1                                                None
# Size: 10^1, Func: agg_sum, Test: 2                                                None
# Size: 10^1, Func: agg_sum, Test: 3                                                None
# Size: 10^1, Func: agg_sum, Test: 4                                                None
# ...                                                                                ...
# Size: 10^4, Func: agg_std, Test: 10  A    7114.660871
# B    7292.077677
# C    7213.07...
# Size: 10^4, Func: agg_std, Test: 11  A    7239.623877
# B    7327.761485
# C    7185.65...
# Size: 10^4, Func: agg_std, Test: 12  A    7298.910956
# B    7208.337953
# C    7268.39...
# Size: 10^4, Func: agg_std, Test: 13  A    7207.527032
# B    7271.465887
# C    7258.80...
# Size: 10^4, Func: agg_std, Test: 14  A    7349.566300
# B    7311.061030
# C    7276.47...
#
#                                                                       Checksum Pandopt  \
# Size: 10^1, Func: agg_sum, Test: 0   0    7.771499
# 1    3.881912
# 2    4.502372
# dtyp...
# Size: 10^1, Func: agg_sum, Test: 1   0   -1.691465
# 1   -2.924282
# 2   -2.050309
# dtyp...
# Size: 10^1, Func: agg_sum, Test: 2   0    4.246821
# 1    3.796359
# 2    2.536170
# dtyp...
# Size: 10^1, Func: agg_sum, Test: 3   0    3.510989
# 1    1.758188
# 2    1.908867
# dtyp...
# Size: 10^1, Func: agg_sum, Test: 4   0     1.888192
# 1     9.075993
# 2    15.703785
# d...
# ...                                                                                ...
# Size: 10^4, Func: agg_std, Test: 10                                               None
# Size: 10^4, Func: agg_std, Test: 11                                               None
# Size: 10^4, Func: agg_std, Test: 12                                               None
# Size: 10^4, Func: agg_std, Test: 13                                               None
# Size: 10^4, Func: agg_std, Test: 14                                               None
#
#                                                                          Pandas Error  \
# Size: 10^1, Func: agg_sum, Test: 0   axis 1 is out of bounds for array of dimension 1
# Size: 10^1, Func: agg_sum, Test: 1   axis 1 is out of bounds for array of dimension 1
# Size: 10^1, Func: agg_sum, Test: 2   axis 1 is out of bounds for array of dimension 1
# Size: 10^1, Func: agg_sum, Test: 3   axis 1 is out of bounds for array of dimension 1
# Size: 10^1, Func: agg_sum, Test: 4   axis 1 is out of bounds for array of dimension 1
# ...                                                                               ...
# Size: 10^4, Func: agg_std, Test: 10                                              None
# Size: 10^4, Func: agg_std, Test: 11                                              None
# Size: 10^4, Func: agg_std, Test: 12                                              None
# Size: 10^4, Func: agg_std, Test: 13                                              None
# Size: 10^4, Func: agg_std, Test: 14                                              None
#
#                                                                   Pandopt Error
# Size: 10^1, Func: agg_sum, Test: 0                                         None
# Size: 10^1, Func: agg_sum, Test: 1                                         None
# Size: 10^1, Func: agg_sum, Test: 2                                         None
# Size: 10^1, Func: agg_sum, Test: 3                                         None
# Size: 10^1, Func: agg_sum, Test: 4                                         None
# ...                                                                         ...
# Size: 10^4, Func: agg_std, Test: 10  DataFrame constructor not properly called!
# Size: 10^4, Func: agg_std, Test: 11  DataFrame constructor not properly called!
# Size: 10^4, Func: agg_std, Test: 12  DataFrame constructor not properly called!
# Size: 10^4, Func: agg_std, Test: 13  DataFrame constructor not properly called!
# Size: 10^4, Func: agg_std, Test: 14  DataFrame constructor not properly called!
#
# [300 rows x 6 columns]

# %%
results_df['time reduction'] = results_df["Pandopt Time (s)"] / results_df["Pandas Time (s)"] - 1
results_df['performance multiplicator'] = results_df["Pandas Time (s)"] / results_df["Pandopt Time (s)"] - 1
results_df
# Out:
#                                      Pandas Time (s)  Pandopt Time (s)  \
# Size: 10^1, Func: agg_sum, Test: 0               NaN          1.243996
# Size: 10^1, Func: agg_sum, Test: 1               NaN          0.000143
# Size: 10^1, Func: agg_sum, Test: 2               NaN          0.000107
# Size: 10^1, Func: agg_sum, Test: 3               NaN          0.000105
# Size: 10^1, Func: agg_sum, Test: 4               NaN          0.000110
# ...                                              ...               ...
# Size: 10^4, Func: agg_std, Test: 10         0.561268               NaN
# Size: 10^4, Func: agg_std, Test: 11         0.562555               NaN
# Size: 10^4, Func: agg_std, Test: 12         0.559817               NaN
# Size: 10^4, Func: agg_std, Test: 13         0.566073               NaN
# Size: 10^4, Func: agg_std, Test: 14         0.561244               NaN
#
#                                                                        Checksum Pandas  \
# Size: 10^1, Func: agg_sum, Test: 0                                                None
# Size: 10^1, Func: agg_sum, Test: 1                                                None
# Size: 10^1, Func: agg_sum, Test: 2                                                None
# Size: 10^1, Func: agg_sum, Test: 3                                                None
# Size: 10^1, Func: agg_sum, Test: 4                                                None
# ...                                                                                ...
# Size: 10^4, Func: agg_std, Test: 10  A    7114.660871
# B    7292.077677
# C    7213.07...
# Size: 10^4, Func: agg_std, Test: 11  A    7239.623877
# B    7327.761485
# C    7185.65...
# Size: 10^4, Func: agg_std, Test: 12  A    7298.910956
# B    7208.337953
# C    7268.39...
# Size: 10^4, Func: agg_std, Test: 13  A    7207.527032
# B    7271.465887
# C    7258.80...
# Size: 10^4, Func: agg_std, Test: 14  A    7349.566300
# B    7311.061030
# C    7276.47...
#
#                                                                       Checksum Pandopt  \
# Size: 10^1, Func: agg_sum, Test: 0   0    7.771499
# 1    3.881912
# 2    4.502372
# dtyp...
# Size: 10^1, Func: agg_sum, Test: 1   0   -1.691465
# 1   -2.924282
# 2   -2.050309
# dtyp...
# Size: 10^1, Func: agg_sum, Test: 2   0    4.246821
# 1    3.796359
# 2    2.536170
# dtyp...
# Size: 10^1, Func: agg_sum, Test: 3   0    3.510989
# 1    1.758188
# 2    1.908867
# dtyp...
# Size: 10^1, Func: agg_sum, Test: 4   0     1.888192
# 1     9.075993
# 2    15.703785
# d...
# ...                                                                                ...
# Size: 10^4, Func: agg_std, Test: 10                                               None
# Size: 10^4, Func: agg_std, Test: 11                                               None
# Size: 10^4, Func: agg_std, Test: 12                                               None
# Size: 10^4, Func: agg_std, Test: 13                                               None
# Size: 10^4, Func: agg_std, Test: 14                                               None
#
#                                                                          Pandas Error  \
# Size: 10^1, Func: agg_sum, Test: 0   axis 1 is out of bounds for array of dimension 1
# Size: 10^1, Func: agg_sum, Test: 1   axis 1 is out of bounds for array of dimension 1
# Size: 10^1, Func: agg_sum, Test: 2   axis 1 is out of bounds for array of dimension 1
# Size: 10^1, Func: agg_sum, Test: 3   axis 1 is out of bounds for array of dimension 1
# Size: 10^1, Func: agg_sum, Test: 4   axis 1 is out of bounds for array of dimension 1
# ...                                                                               ...
# Size: 10^4, Func: agg_std, Test: 10                                              None
# Size: 10^4, Func: agg_std, Test: 11                                              None
# Size: 10^4, Func: agg_std, Test: 12                                              None
# Size: 10^4, Func: agg_std, Test: 13                                              None
# Size: 10^4, Func: agg_std, Test: 14                                              None
#
#                                                                   Pandopt Error  \
# Size: 10^1, Func: agg_sum, Test: 0                                         None
# Size: 10^1, Func: agg_sum, Test: 1                                         None
# Size: 10^1, Func: agg_sum, Test: 2                                         None
# Size: 10^1, Func: agg_sum, Test: 3                                         None
# Size: 10^1, Func: agg_sum, Test: 4                                         None
# ...                                                                         ...
# Size: 10^4, Func: agg_std, Test: 10  DataFrame constructor not properly called!
# Size: 10^4, Func: agg_std, Test: 11  DataFrame constructor not properly called!
# Size: 10^4, Func: agg_std, Test: 12  DataFrame constructor not properly called!
# Size: 10^4, Func: agg_std, Test: 13  DataFrame constructor not properly called!
# Size: 10^4, Func: agg_std, Test: 14  DataFrame constructor not properly called!
#
#                                      time reduction  performance multiplicator
# Size: 10^1, Func: agg_sum, Test: 0              NaN                        NaN
# Size: 10^1, Func: agg_sum, Test: 1              NaN                        NaN
# Size: 10^1, Func: agg_sum, Test: 2              NaN                        NaN
# Size: 10^1, Func: agg_sum, Test: 3              NaN                        NaN
# Size: 10^1, Func: agg_sum, Test: 4              NaN                        NaN
# ...                                             ...                        ...
# Size: 10^4, Func: agg_std, Test: 10             NaN                        NaN
# Size: 10^4, Func: agg_std, Test: 11             NaN                        NaN
# Size: 10^4, Func: agg_std, Test: 12             NaN                        NaN
# Size: 10^4, Func: agg_std, Test: 13             NaN                        NaN
# Size: 10^4, Func: agg_std, Test: 14             NaN                        NaN
#
# [300 rows x 8 columns]

# %%
results_df.to_csv('benchmark.csv')

# %%
results_df['performance multiplicator'].dropna(
    
)
# Out:
# Series([], Name: performance multiplicator, dtype: float64)
