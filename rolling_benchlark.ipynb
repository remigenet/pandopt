# %%
from PandOpt import pandopt
import pandas as pd
import numpy as np
import tqdm 
import pandas as pd
import numpy as np
import timeit
import functools
import time


def agg_sum(z):
    return np.sum(z)

def agg_mean(z):
    return np.mean(z)

def agg_max(z):
    return np.max(z)

def agg_min(z):
    return np.min(z)

def agg_std(z):
    return np.std(z)

def agg_sum(z):
    return np.sum(z)

def agg_custom(z):
    # NOT HANDLED YET
    print(z.shape)
    if z['A',-1] > z['B',0]:
        return np.median(z['C']) - np.std(np.log(z))
    return np.mean(z["C"]) / 2 / np.std(z)

# %%
# import polars as pl

def agg_sum(z):
    return np.sum(z)
    
for ten_exponant in range(4,9):
    dfsize=int(10**ten_exponant)
    print(f'testing 1e{ten_exponant}')
    pandas_df = pd.DataFrame(np.random.randn(dfsize, 4), columns=['A', 'B', 'C', 'D']).astype(np.float32)
    pandopt_df = pandopt(pandas_df)
    # polars_df = pl.DataFrame(pandas_df)
    
    if ten_exponant < 6:

        t1 = time.time()
        pandas_apply = pandas_df.rolling(25).apply(agg_sum)
        t2=time.time()
        print('pandas apply: ', pandas_apply.shape, end=' ')
        pandas_applyS = np.max(pandas_apply.to_numpy())
        print(pandas_applyS, (t3:=time.time()) - t2, t2 - t1, t3-t1)

    t1 = time.time()
    pandas_sum = pandas_df.rolling(25).sum()
    t2=time.time()
    print('pandas sum: ', pandas_sum.shape, end=' ')
    pandas_sumS = np.max(pandas_apply.to_numpy())
    print(pandas_sumS, (t3:=time.time()) - t2, t2 - t1, t3-t1)

    t1 = time.time()
    pandopt_apply = pandopt_df.rolling(25).apply(agg_sum)
    t2=time.time()
    print('pandopt apply: ', pandopt_apply.shape, end=' ')
    pandopt_applyS = np.max(pandopt_apply.to_numpy())
    print(pandopt_applyS, (t3:=time.time()) - t2, t2 - t1, t3-t1)

    # t1 = time.time()
    # pandopt_apply = pandopt_df.rolling(25).sum()
    # t2=time.time()
    # print('pandopt apply: ', pandopt_apply.shape, end=' ')
    # pandopt_applyS = np.max(pandopt_apply.to_numpy())
    # print(pandopt_applyS, (t3:=time.time()) - t2, t2 - t1, t3-t1)
    
    print()




    #No direct equivalent in two bellows
    
    # array = pandas_df.to_numpy()
    # t1 = time.time()
    # np_sum =  np.sum(array, axis=1)
    # t2=time.time()
    # print('numpy sum: ', np_sum.shape, end=' ')
    # np_sumS = np.sum(np_sum)
    # print(np_sumS, (t3:=time.time()) - t2, t2 - t1, t3-t1)


    # t1 = time.time()
    # polars_sum = polars_df.sum_horizontal()
    # t2=time.time()
    # print('polars sum: ', polars_sum.shape, end=' ')
    # polars_sumS = np.sum(polars_sum.to_numpy())
    # print(polars_sumS, (t3:=time.time()) - t2, t2 - t1, t3-t1)
# Out:
# testing 1e4
# pandas apply:  (10000, 4) nan 0.00024127960205078125 1.4711248874664307 1.4713661670684814
# pandas sum:  (10000, 4) nan 3.5762786865234375e-05 0.0007495880126953125 0.0007853507995605469
# pandopt apply:  (9976, 4) 24.2168025970459 0.00025081634521484375 4.005364656448364 4.005615472793579
#
# testing 1e5
# pandas apply:  (100000, 4) nan 0.0002505779266357422 15.045182466506958 15.045433044433594
# pandas sum:  (100000, 4) nan 0.0001266002655029297 0.003753662109375 0.0038802623748779297
# pandopt apply:  (99976, 4) 21.459680557250977 0.00015401840209960938 0.0015959739685058594 0.0017499923706054688
#
# testing 1e6
# pandas sum:  (1000000, 4) nan 0.00019669532775878906 0.04828381538391113 0.04848051071166992
# pandopt apply:  (999976, 4) 26.947368621826172 0.0014450550079345703 0.021910667419433594 0.023355722427368164
#
# testing 1e7
# pandas sum:  (10000000, 4) nan 0.0002906322479248047 0.5452125072479248 0.5455031394958496
# ...

# %%
    

for ten_exponant in range(4,9):
    dfsize=int(10**ten_exponant)
    print(f'testing 1e{ten_exponant}')
    pandas_df = pd.DataFrame(np.random.randn(dfsize, 4), columns=['A', 'B', 'C', 'D']).astype(np.float32)
    pandopt_df = pandopt(pandas_df)
    # polars_df = pl.DataFrame(pandas_df)
    
    if ten_exponant < 6:

        t1 = time.time()
        pandas_apply = pandas_df.apply(agg_sum, axis=1).rolling(25).apply(agg_sum)
        t2=time.time()
        print('pandas apply axis 1 + roll apply: ', pandas_apply.shape, end=' ')
        pandas_applyS = np.max(pandas_apply.to_numpy())
        print(pandas_applyS, (t3:=time.time()) - t2, t2 - t1, t3-t1)

    t1 = time.time()
    pandas_sum = pandas_df.sum(axis=1).rolling(25).sum()
    t2=time.time()
    print('pandas sum axis1 + roll sum: ', pandas_sum.shape, end=' ')
    pandas_sumS = np.max(pandas_apply.to_numpy())
    print(pandas_sumS, (t3:=time.time()) - t2, t2 - t1, t3-t1)


    #No direct equivalent in two bellows
    
    # array = pandas_df.to_numpy()
    # t1 = time.time()
    # np_sum =  np.sum(array, axis=1)
    # t2=time.time()
    # print('numpy sum: ', np_sum.shape, end=' ')
    # np_sumS = np.sum(np_sum)
    # print(np_sumS, (t3:=time.time()) - t2, t2 - t1, t3-t1)


    # t1 = time.time()
    # polars_sum = polars_df.sum_horizontal()
    # t2=time.time()
    # print('polars sum: ', polars_sum.shape, end=' ')
    # polars_sumS = np.sum(polars_sum.to_numpy())
    # print(polars_sumS, (t3:=time.time()) - t2, t2 - t1, t3-t1)

    pandas_df = pd.DataFrame(np.random.randn(dfsize, 4), columns=['A', 'B', 'C', 'D']).astype(np.float32)
    t1 = time.time()
    pandopt_apply = pandopt_df.rolling(25).apply(agg_sum, axis=1)
    t2=time.time()
    print('pandopt apply axis1: ', pandopt_apply.shape, end=' ')
    pandopt_applyS = np.max(pandopt_apply.to_numpy())
    print(pandopt_applyS, (t3:=time.time()) - t2, t2 - t1, t3-t1)

    # pandas_df = pd.DataFrame(np.random.randn(dfsize, 4), columns=['A', 'B', 'C', 'D']).astype(np.float32)
    # t1 = time.time()
    # pandopt_apply = pandopt_df.rolling(25).sum(axis=1)
    # t2=time.time()
    # print('pandopt sum axis1: ', pandopt_apply.shape, end=' ')
    # pandopt_applyS = np.max(pandopt_apply.to_numpy())
    # print(pandopt_applyS, (t3:=time.time()) - t2, t2 - t1, t3-t1)

    print()
# Out:
# testing 1e4
# pandas apply axis 1 + roll apply:  (10000,) nan 9.393692016601562e-05 0.5827603340148926 0.5828542709350586
# pandas sum axis1 + roll sum:  (10000,) nan 7.319450378417969e-05 0.01010894775390625 0.01018214225769043
# pandopt apply axis1:  (9976, 1) 31.541303634643555 0.0004494190216064453 1.5943410396575928 1.5947904586791992
#
# testing 1e5
# pandas apply axis 1 + roll apply:  (100000,) nan 0.0002970695495605469 5.850049018859863 5.850346088409424
# pandas sum axis1 + roll sum:  (100000,) nan 6.508827209472656e-05 0.009685993194580078 0.009751081466674805
# pandopt apply axis1:  (99976, 1) 45.721923828125 6.270408630371094e-05 0.00083160400390625 0.0008943080902099609
#
# testing 1e6
# pandas sum axis1 + roll sum:  (1000000,) nan 9.989738464355469e-05 0.09582686424255371 0.09592676162719727
# pandopt apply axis1:  (999976, 1) 46.1475944519043 0.00036597251892089844 0.004106044769287109 0.004472017288208008
#
# testing 1e7
# ...

# %%
def measure_performance(df, func, window_size=3):
    try:
        if type(df)==pandopt:
            operation = functools.partial(df.rolling(window=window_size).apply, func, axis = 0,raw=True)
        else:
            operation = functools.partial(df.rolling(window=window_size).apply, func, raw=True)
        start_time = timeit.default_timer()
        result = operation()
        elapsed_time = timeit.default_timer() - start_time
        return np.sum(result.dropna().values), elapsed_time, None
    except Exception as e:
        return None, None, str(e)

def run_tests(data_size, agg_funcs):
    results = {}
    total_tests = (data_size - 1) * len(agg_funcs) 
    progress_bar = tqdm.tqdm(total=total_tests, desc="Running Tests", ncols=100)

    for test_num in range(1, data_size):
        df_size = int(10**test_num)
        for func in agg_funcs:
            for test_iter in range(15):
                pandas_df = pd.DataFrame(np.random.randn(df_size, 4), columns=['A', 'B', 'C', 'D']).astype(np.float32)
                pandopt_df = pandopt(pandas_df)
                pandas_checksum, pandas_time, pandas_error = measure_performance(pandas_df, func)
                pandopt_checksum, pandopt_time, pandopt_error = measure_performance(pandopt_df, func)

                key = f"Size: 10^{test_num}, Func: {func.__name__}, Test: {test_type} - {test_iter}"
                results[key] = {
                    "Size":df_size,
                    "function": func.__name__, 
                    "test_type": test_type, 
                    "test_iter": test_iter,
                    "Pandas Time (s)": pandas_time,
                    "Pandopt Time (s)": pandopt_time,
                    "Checksum Pandas": pandas_checksum,
                    "Checksum Pandopt": pandopt_checksum,
                    "Pandas Error": pandas_error,
                    "Pandopt Error": pandopt_error
                }

            progress_bar.update(1)

    progress_bar.close()
    return pd.DataFrame.from_dict(results, orient='index')

agg_functions = [agg_sum, agg_mean, agg_max, agg_min, agg_std]

results_df = run_tests(data_size=5, agg_funcs=agg_functions)
results_df
# Out:
# Running Tests:   0%|                                                         | 0/20 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 49
#      45     return pd.DataFrame.from_dict(results, orient='index')
#      47 agg_functions = [agg_sum, agg_mean, agg_max, agg_min, agg_std]
# ---> 49 results_df = run_tests(data_size=5, agg_funcs=agg_functions)
#      50 results_df
#
# Cell In[4], line 28, in run_tests(data_size, agg_funcs)
#      25     pandas_checksum, pandas_time, pandas_error = measure_performance(pandas_df, func)
#      26     pandopt_checksum, pandopt_time, pandopt_error = measure_performance(pandopt_df, func)
# ---> 28     key = f"Size: 10^{test_num}, Func: {func.__name__}, Test: {test_type} - {test_iter}"
#      29     results[key] = {
#      30         "Size":df_size,
#      31         "function": func.__name__,
#    (...)
# ...

# %%
results_df['time reduction'] = results_df["Pandopt Time (s)"] / results_df["Pandas Time (s)"] - 1
results_df['performance multiplicator'] = results_df["Pandas Time (s)"] / results_df["Pandopt Time (s)"] - 1
results_df

# %%
results_df.to_csv('benchmark.csv')
results_df

# %%
measure_performance(pandas_df, agg_mean, 5)
